# %% [markdown]
# * MongoDB Compass
#     * `https://<username>:<pw>@localhost:<port>`

# %%
from debug import DebugDatabases

# %%
debug_db = DebugDatabases(mongo_port=37030, postgres_port=35450)
debug_db.create_infrastructure()
debug_db.write_test_mongo()
# Out:
# INFO:docker_tester.docker_management:REMOVE docker network HihiPostgreSQL and postgres-container HihiPostgreSQL!
# INFO:docker_tester.docker_management:REMOVE docker network MongoNuzzlesOwO and postgres-container MongoNuzzlesOwO!
# INFO:docker_tester.docker_management:Setting up MongoDB server 'MongoNuzzlesOwO' on network 'MongoNuzzlesOwO'
# INFO:docker_tester.docker_management:MongoDB server 'MongoNuzzlesOwO' is up and running.
# INFO:docker_tester.docker_management:CREATE docker network HihiPostgreSQL and postgres-container HihiPostgreSQL!

# %%
print(debug_db.db_password)
# Out:
# f21e2bda43f31b48

# %%
import pymongo
client = pymongo.MongoClient(host='localhost', port=debug_db.mongo_port, username='mongo', password=debug_db.db_password)
db = client['testing']
collection = db['collie']
collection.find()[0]
# Out:
# {'_id': {'oid': '679251093086a3fc4f59be7a'},
#  'collaborative': False,
#  'description': 'my favorite tracks, updated weekly :)',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/6SicuY0mHh1ZP8oXuD71kh'},
#  'href': 'https://api.spotify.com/v1/playlists/6SicuY0mHh1ZP8oXuD71kh',
#  'id': '6SicuY0mHh1ZP8oXuD71kh',
#  'images': [{'height': None,
#    'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da844b6f8311f2f6b0485cb2b7e1',
#    'width': None}],
#  'name': 'ANDREA BOTEZ  [ DARK TECHNO ]',
#  'owner': {'display_name': 'Andrea Botez',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/andrea-botez'},
#   'href': 'https://api.spotify.com/v1/users/andrea-botez',
#   'id': 'andrea-botez',
#   'type': 'user',
#   'uri': 'spotify:user:andrea-botez'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'AAAEX50tkShPiIdUwamqlGkJW0gJItLe',
#  'tracks': [{'added_at': '2024-11-05T21:29:23Z',
# ...

# %%
debug_db.remove_infrastructure()
